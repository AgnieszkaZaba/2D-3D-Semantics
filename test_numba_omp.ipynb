# %% [markdown]
# <a href="https://colab.research.google.com/github/AgnieszkaZaba/2D-3D-Semantics/blob/master/test_numba_omp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet numba
import os
os.environ['NUMBA_THREADING_LAYER'] = 'workqueue'
import numba
def f():
  for i in numba.prange(2):
    print(i)
numba.njit(f, parallel=True)()
print(numba.config.THREADING_LAYER)
# Out:
# 10
#
# workqueue
